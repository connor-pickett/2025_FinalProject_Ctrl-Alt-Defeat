# %%
pip install nfl-data-py
# Out:
# ...
#   Using cached pandas-1.5.3-cp312-cp312-macosx_11_0_arm64.whl
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dask-expr 1.1.0 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nfl_data_py as nfl

# %%
seasons = [2000]  # You can also pass multiple seasons, e.g., [2000, 2001, 2002]

# Fetch play-by-play data
df = nfl.import_pbp_data(seasons)
# Out:
# 2000 done.
# Downcasting floats.

# %%
df
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/formatters.py:347: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
#        play_id          game_id old_game_id home_team away_team season_type
# 0         34.0  2000_01_ARI_NYG  2000090300       NYG       ARI         REG  \
# 1         70.0  2000_01_ARI_NYG  2000090300       NYG       ARI         REG
# 2        106.0  2000_01_ARI_NYG  2000090300       NYG       ARI         REG
# 3        131.0  2000_01_ARI_NYG  2000090300       NYG       ARI         REG
# 4        148.0  2000_01_ARI_NYG  2000090300       NYG       ARI         REG
# ...        ...              ...         ...       ...       ...         ...
# 45486   3691.0  2000_21_BAL_NYG  2001012800       NYG       BAL        POST
# 45487   3712.0  2000_21_BAL_NYG  2001012800       NYG       BAL        POST
# ...

# %%
target_years = [2019]
pbp_cache_path = 'data/pbp'
nfl.cache_pbp(target_years, alt_path=pbp_cache_path)
pbp = nfl.import_pbp_data(target_years, cache=True, alt_path=pbp_cache_path)
print(pbp[(pbp.play_type == 'kickoff') & (pbp.kick_distance.isna())][['desc', 'game_id']])
print(pbp[pbp.game_id == '2019_15_CLE_ARI'][['desc', 'time', 'play_type']].head(20))
# Out:
# 2019 done.
# 2019 done.
# Downcasting floats.
#                                                     desc          game_id
# 37414  (10:15) (No Huddle, Shotgun) 41-K.Drake left e...  2019_15_CLE_ARI
#                                                     desc   time    play_type
# 37403                                               GAME  15:00         None
# 37404  5-Z.Gonzalez kicks 65 yards from ARI 35 to end...  15:00      kickoff
# 37405  (15:00) 24-N.Chubb to CLE 44 for 19 yards (23-...  15:00          run
# 37406  (14:30) 6-B.Mayfield pass deep right to 13-O.B...  14:30         pass
# 37407  (14:23) (No Huddle, Shotgun) 1-K.Murray pass s...  14:23         pass
# 37408  4-A.Seibert extra point is GOOD, Center-47-C.H...  14:12  extra_point
# 37409  4-A.Seibert kicks 65 yards from CLE 35 to end ...  14:12      kickoff
# 37410  (14:12) 1-K.Murray pass short left to 11-L.Fit...  14:12         pass
# 37411         (14:12) 41-K.Drake for 2 yards, TOUCHDOWN.  14:12          run
# ...

# %%
hi=nfl.import_weekly_data([2000, 2005])
print(hi[hi["player_display_name"] == "Madison Hedgecock"])
# Out:
# Downcasting floats.
#        player_id player_name player_display_name position position_group
# 4631  00-0023683        None   Madison Hedgecock       FB             RB  \
# 4632  00-0023683        None   Madison Hedgecock       FB             RB
# 4633  00-0023683        None   Madison Hedgecock       FB             RB
# 4634  00-0023683        None   Madison Hedgecock       FB             RB
# 4635  00-0023683        None   Madison Hedgecock       FB             RB
# 4636  00-0023683        None   Madison Hedgecock       FB             RB
# 4637  00-0023683        None   Madison Hedgecock       FB             RB
#
#      headshot_url recent_team  season  week season_type  ...
# 4631         None          LA    2005     4         REG  ...  \
# 4632         None          LA    2005    11         REG  ...
# 4633         None          LA    2005    12         REG  ...
# 4634         None          LA    2005    13         REG  ...
# ...
